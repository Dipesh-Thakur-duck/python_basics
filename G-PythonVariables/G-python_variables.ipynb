# %% [markdown]
# # Python Varibales

# %% [markdown]
# ## Variables
# Variables are containers for storing data values.

# %% [markdown]
# ## Creating Variables
# Python has no command for declaring a variable. A variable is created the moment you first assign a value to it.

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %% [markdown]
# Variables do not need to be declared with any particular <i>type</i>, and can even change type after they have been set.

# %%
x = 4 # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %% [markdown]
# ## Casting
# If you want to specify the data type of a variable, this can be done with casting.

# %%
x = str(3) # x will be '3'
y = int(3) # y will be 3
z = float(3) # z will be 3.0

# %% [markdown]
# ## Get the Type
# You can get the data type of a variable with the <mark>type()</mark> function.

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## Single or Double Quotes?
# String Variables can be declared either by using single or double quotes.

# %%
x = "John"
# is the same as
x = "John"

# %% [markdown]
# ## Case Sensitive
# Variable names are case-sensitive.

# %%
a = 4
A = 'Sally'
#A will not overwrite a
