# %% [markdown]
# # Python - Escape Characters
# An escape character (\\) is used in a string to represent special characters or to prevent certain characters from being interpreted in their usual way.
# \\ is the escape character itself, and it gives special meaning to the character(s) that follow it.

# %%
txt = "We are the so-called \"vikings\" from the north."
print(txt)
# Out:
# We are the so-called "vikings" from the north.
